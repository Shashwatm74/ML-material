# %%
# !pip install numpy
# !pip install matplotlib
# !pip install pandas
# !pip install seaborn
# !pip install pyarrow
# !pip install numexpr
# !pip install scikit-learn
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\shash\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\shash\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\shash\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: C:\Users\shash\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Location1.csv')
df.head()
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            28.5                   85         24.5
# 1  2017-01-02 01:00:00            28.4                   86         24.7
# 2  2017-01-02 02:00:00            26.8                   91         24.5
# 3  2017-01-02 03:00:00            27.4                   88         24.3
# 4  2017-01-02 04:00:00            27.3                   88         24.1
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           1.44            1.26                146                 162
# 1           2.06            3.99                151                 158
# 2           1.30            2.78                148                 150
# 3           1.30            2.69                 58                 105
# 4           2.47            4.43                 58                  84
#
#    windgusts_10m   Power
# 0            1.4  0.1635
# 1            4.4  0.1424
# ...

# %%
df.drop('Time', axis=1, inplace=True)

# %%
df.head()
# Out:
#    temperature_2m  relativehumidity_2m  dewpoint_2m  windspeed_10m  \
# 0            28.5                   85         24.5           1.44
# 1            28.4                   86         24.7           2.06
# 2            26.8                   91         24.5           1.30
# 3            27.4                   88         24.3           1.30
# 4            27.3                   88         24.1           2.47
#
#    windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# 0            1.26                146                 162            1.4
# 1            3.99                151                 158            4.4
# 2            2.78                148                 150            3.2
# 3            2.69                 58                 105            1.6
# 4            4.43                 58                  84            4.0
#
#     Power
# 0  0.1635
# 1  0.1424
# 2  0.1214
# 3  0.1003
# 4  0.0793

# %%
X = df.iloc[:, :-1].values
X
# Out:
# array([[ 28.5,  85. ,  24.5, ..., 146. , 162. ,   1.4],
#        [ 28.4,  86. ,  24.7, ..., 151. , 158. ,   4.4],
#        [ 26.8,  91. ,  24.5, ..., 148. , 150. ,   3.2],
#        ...,
#        [ 34.1,  95. ,  33. , ..., 360. ,  45. ,   4.3],
#        [ 34.4,  96. ,  33.5, ...,  45. ,  51. ,   4.2],
#        [ 35. ,  97. ,  34.2, ...,  45. ,  51. ,   4.3]])

# %%
y = df.iloc[:,-1].values
y
# Out:
# array([0.1635, 0.1424, 0.1214, ..., 0.2336, 0.2606, 0.2877])

# %%
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >

# %%
df.drop('temperature_2m', axis=1, inplace=True)
df.drop('relativehumidity_2m', axis=1, inplace=True)
df.drop('dewpoint_2m', axis=1, inplace=True)

# %%
df.head()
# Out:
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           1.44            1.26                146                 162
# 1           2.06            3.99                151                 158
# 2           1.30            2.78                148                 150
# 3           1.30            2.69                 58                 105
# 4           2.47            4.43                 58                  84
#
#    windgusts_10m   Power
# 0            1.4  0.1635
# 1            4.4  0.1424
# 2            3.2  0.1214
# 3            1.6  0.1003
# 4            4.0  0.0793

# %%
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# windspeed_10m         0
# windspeed_100m        0
# winddirection_10m     0
# winddirection_100m    0
# windgusts_10m         0
# Power                 0
# dtype: int64

# %%
for k in numeric_df:
    if k != 'Power':
        df.groupby([k])['Power'].mean().plot.bar()
        plt.yscale('symlog')  # Change the scale of the y-axis to logarithmic
        plt.xscale('symlog')  # Change the scale of the x-axis to logarithmic
        plt.show()

# %%
num = df.select_dtypes(exclude = ['object'])
for k in num:
    if k != 'Power':
        plt.scatter(df[k],df['Power'])
        plt.title(k)
        plt.yscale('log')  # Change the scale of the y-axis to logarithmic
        plt.xscale('log')  # Change the scale of the x-axis to logarithmic

        plt.show()

# %%
for k in num:
    if k != 'Power':
        sns.distplot(df[k])
        plt.title(k)
        plt.show()
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_87580\1201686649.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[k])
# C:\Users\shash\AppData\Local\Temp\ipykernel_87580\1201686649.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[k])
# ...

# %%
for k in num:
    if k != 'Power':
        sns.boxplot(df[k])
        plt.title(k)
        plt.show()

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:,-1].values
print(X)
print(y)
# Out:
# [[  1.44   1.26 146.   162.     1.4 ]
#  [  2.06   3.99 151.   158.     4.4 ]
#  [  1.3    2.78 148.   150.     3.2 ]
#  ...
#  [  1.1    1.84 360.    45.     4.3 ]
#  [  2.4    4.62  45.    51.     4.2 ]
#  [  2.26   5.04  45.    51.     4.3 ]]
# [0.1635 0.1424 0.1214 ... 0.2336 0.2606 0.2877]

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

labelencoder = LabelEncoder()
X[:, 3] = labelencoder.fit_transform(X[:, 3])
onehotencoder = ColumnTransformer(
    transformers = [
        ("OneHot", #name
        OneHotEncoder(),# transformer class
        [3] #columns to be applied on
        )
    ],
    remainder = 'passthrough' # donot apply anything to the remaining columns
)
X = onehotencoder.fit_transform(X)

# %%
X = X[:,1:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([0.75081702, 0.78605972, 0.74408495, ..., 0.51930152, 0.68394114,
#        0.19751482])

# %%
print(regressor.coef_)
# Out:
# [ 4.41022279e-03 -3.34220654e-02  4.50594105e-02  3.88352432e-02
#  -4.03407232e-03  1.73949963e-02  8.74437649e-03  2.60369042e-02
#   9.19988798e-03 -9.87336526e-03  2.53374544e-02 -2.49610784e-02
#   2.04993210e-02 -8.68848971e-04 -8.01989617e-03 -1.36004421e-02
#  -6.42353552e-03  6.58003090e-03  1.12145191e-02 -3.06618408e-02
#  -1.28615365e-02 -1.41100504e-02  5.18204556e-03  8.83594562e-03
#  -2.87801947e-02  2.40216723e-02 -4.60267261e-03 -2.74899128e-02
#  -2.80381715e-02  3.48755861e-02 -3.10664622e-02 -1.66107977e-02
#  -4.24867559e-02  2.08947337e-03 -3.43419788e-02 -3.18470446e-02
#  -1.86852495e-02 -5.36293181e-02  1.92584857e-02 -4.88144518e-02
#  -7.95518309e-03 -7.96516698e-03 -6.76804577e-02 -8.34019553e-02
#  -3.33300977e-02 -3.37528940e-02 -5.28885987e-02 -6.13713085e-02
#  -5.85963927e-02 -6.21637361e-02 -7.60511288e-02 -7.33650516e-02
#  -7.90322870e-02 -4.71548115e-02 -9.37743123e-02 -4.90377785e-02
# ...

# %%
print(regressor.intercept_)
# Out:
# -0.12185938547544783

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.595551744191037

# %%
plt.scatter(y_test, y_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted')
plt.show()
